# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt

# %%
url = "usuarios_win_mac_lin.csv"
datos = pd.read_csv(url)

X = datos.drop('clase', axis=1)
y = datos['clase']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y)

model = LogisticRegression(max_iter=1500)
model.fit(X_train, y_train)
print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
y_pred = model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=['Windows', 'Mac', 'Linux'])
cmd.plot()
# Out:
# 0.7874015748031497
# 0.7209302325581395

# %%
X_new = [10,3,5,9]
model.predict([X_new])
# Out:
# /home/luis/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([2])
