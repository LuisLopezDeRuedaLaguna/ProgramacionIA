# %% [markdown]
# En lugar de un script de Python (.py) vamos a usar un cuaderno de Jupyter.
# Podemos usar subprocesos:

# %%
import subprocess

#Creamos un subproceso que ejecutará el ppt (o lo que haga falta):
subproceso = subprocess.run(["ppt"], capture_output=True, text=True)

#Recogemos la salida del subproceso, que será una cadena con espacios en blancos y \n:
jugadas = subproceso.stdout
print("--- Jugadas como cadena ---")
print(jugadas[0:100]) #mostramos los primeros 100 caracteres

#Vamos a convertir la cadena con las jugadas en una lista:
jugadas = jugadas.strip(' \n') #quitamos los espacios en blanco y \n del principio y el final
jugadas = list(jugadas.split('\n')) #convertimos en una lista (separando por los \n)
diccionario = {'Piedra': 0, 'Papel': 0, 'Tijera': 0}

for i in jugadas:
    diccionario[i] += valor

print(f"Conteos finales: {diccionario}")
# Out:
# --- Jugadas como cadena ---
# Piedra
# Piedra
# Tijera
# Piedra
# Papel
# Tijera
# Piedra
# Piedra
# Tijera
# Tijera
# Tijera
# Tijera
# Piedra
# Piedra
# Tij
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 16
#      13 jugadas = list(jugadas.split('\n')) #convertimos en una lista (separando por los \n)
#      14 diccionario = {'Piedra': 0, 'Papel': 0, 'Tijera': 0}
# ---> 16 for clave, valor in jugadas.items():
#      17     diccionario[clave] += valor
#      19 print(f"Conteos finales: {diccionario}")
#
# AttributeError: 'list' object has no attribute 'items'
